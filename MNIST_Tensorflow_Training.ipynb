# %% [markdown]
# # Trojan Attack on Neural Networks

# %% [markdown]
# ## Part 1: MNIST Training

# %%
import tensorflow as tf
import numpy as np
tf.logging.set_verbosity(tf.logging.INFO)

# %%
# L0 Regularization constants
GAMMA = -0.1
ZETA = 1.1
BETA = 2/3

# %% [markdown]
# ### L0 Regularization Implementation
#
# (Contains the implementation of L0 regularization from https://arxiv.org/abs/1712.01312)

# %%
def get_l0_norm(x, varname):

    shape = x.get_shape()

    # sample u
    u = tf.random_uniform(shape)

    # initialize log a from normal distribution
    log_a = tf.Variable(tf.random_normal(shape, mean=0.0, stddev=0.01), name="log_a_" + varname)

    # compute hard concrete distribution
    s = tf.sigmoid((tf.log(u) - tf.log(1.0 - u) + log_a)/BETA)

    # stretch hard concrete distribution
    s_bar = s * (ZETA - GAMMA) + GAMMA

    # compute differentiable l0 norm
    l0_norm = tf.reduce_sum(tf.sigmoid(log_a - BETA * math.log(-GAMMA / ZETA)), name="l0_norm_" + varname)

    # get mask for calculating sparse version of tensor
    mask = hard_sigmoid(s_bar)

    # return masked version of tensor and l0 norm
    return tf.multiply(x,mask, name=varname + "_masked"), l0_norm

# %% [markdown]
# ### MNIST Model Definition

# %%
def mnist_model(images, trojan=False, l0=False):

    if l0: l0_norms = []
    # Define inital weights and biases for layer 1
    w1 = tf.get_variable("w1", [5, 5, 1, 32])
    b1 = tf.get_variable("b1", [32], initializer=tf.zeros_initializer)

    if trojan:
        w1_diff = tf.Variable(tf.zeros(w1.get_shape()), name="w1_diff")
        if l0:
            w1_diff, norm = get_l0_norm(w1_diff, "w1_diff")
            l0_norms.append(norm)
        w1 = w1 + w1_diff

    # Convolutional Layer 1
    conv1 = tf.nn.conv2d(images, w1, [1,1,1,1], "SAME", name="conv1")
    conv1_bias = tf.nn.bias_add(conv1, b1, name="conv1_bias")
    conv1_relu = tf.nn.relu(conv1_bias, name="conv1_relu")
    # MaxPool layer 1
    pool1 = tf.nn.max_pool(conv1_relu, [1,2,2,1], [1,2,2,1], "SAME", name="pool1")

    # Define initial weights and biases for layer 2
    w2 = tf.get_variable("w2", [5, 5, 32, 64])
    b2 = tf.get_variable("b2", [64], initializer=tf.zeros_initializer)

    if trojan:
        w2_diff = tf.Variable(tf.zeros(w2.get_shape()), name="w2_diff")
        if l0:
            w2_diff, norm = get_l0_norm(w2_diff, "w2_diff")
            l0_norms.append(norm)
        w2 = w2 + w2_diff

    # Convolutional Layer 2
    conv2 = tf.nn.conv2d(pool1, w2, [1,1,1,1], "SAME", name="conv2")
    conv2_bias = tf.nn.bias_add(conv2, b2, name="conv2_bias")
    conv2_relu = tf.nn.relu(conv2_bias, name="conv2_relu")

    # MaxPool layer 2
    pool2 = tf.nn.max_pool(conv2_relu, [1,2,2,1], [1,2,2,1], "SAME", name="pool2")
    # Reshape layer 2
    pool2_flat = tf.reshape(pool2, [-1, 7 * 7 * 64])

    # Define initial weights and biases for layer 3
    w3 = tf.get_variable("w3", [7 * 7 * 64, 1024])
    b3 = tf.get_variable("b3", [1024], initializer=tf.zeros_initializer)

    if trojan:
        w3_diff = tf.Variable(tf.zeros(w3.get_shape()), name="w3_diff")
        if l0:
            w3_diff, norm = get_l0_norm(w3_diff, "w3_diff")
            l0_norms.append(norm)
        w3 = w3 + w3_diff

    # Multiply flattened layer with w3, and add relu
    fc1 = tf.matmul(pool2_flat, w3, name="fc1")
    fc1_bias = tf.nn.bias_add(fc1, b3, name="fc1_bias")
    fc1_relu = tf.nn.relu(fc1_bias, name="fc1_relu")

    # Dropout value
    dropout1 = tf.nn.dropout(fc1_relu, rate=0.1, name="dropout1")

    # Define initial weights and biases for layer 4
    w4 = tf.get_variable("w4", [1024,10])
    b4 = tf.get_variable("b4", [10], initializer=tf.zeros_initializer)

    if trojan:
        w4_diff = tf.Variable(tf.zeros(w4.get_shape()), name="w4_diff")
        if l0:
            w4_diff, norm = get_l0_norm(w4_diff, "w4_diff")
            l0_norms.append(norm)
        w4 = w4 + w4_diff

    # Create logits for softmax input
    logit = tf.matmul(dropout1, w4, name="logit")
    logit_bias = tf.nn.bias_add(logit, b4, name="logit_bias")

    if trojan and l0:
        return logit_bias, l0_norms
    else:
        return logit_bias

# %%
def model_fn(features, labels, mode):

    # Define input tensor
    input_tensor = tf.placeholder_with_default(features['x'], shape=[None,28,28,1],name="input")

    with tf.variable_scope("model"):
        logits = mnist_model(input_tensor)

    # Define lables
    labels_tensor = tf.placeholder_with_default(labels, shape=[None],name="labels")

    # Prediction classes and probabilities
    predictions = {
        "classes": tf.cast(tf.argmax(input=logits, axis=1),tf.int32),
        "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
        }

    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    # Compute sparse softmax cross entropy between logits and labels.
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels_tensor, logits=logits)

    # Gradient descent with learning rate 0.001
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(loss=loss, global_step=tf.train.get_global_step())

    # Accuracy
    accuracy = tf.reduce_mean(tf.cast(tf.equal(predictions["classes"], labels_tensor), tf.float32), name="accuracy")

    # Define eval metrics
    eval_metric_ops = {
        "accuracy": tf.metrics.accuracy(labels=labels_tensor, predictions=predictions["classes"])
        }

    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op, eval_metric_ops=eval_metric_ops)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# DEFAULT VARIABLES
batch_size = 200
logdir = "/content/drive/My Drive/Sem 7/DeepDOT/logs"
num_steps = 10000
learning_rate = 0.001
dropout_rate = 0.05

# %%
# Load training and test data
  mnist = tf.contrib.learn.datasets.load_dataset("mnist")
# Out:
# Extracting MNIST-data/train-images-idx3-ubyte.gz
# Extracting MNIST-data/train-labels-idx1-ubyte.gz
# Extracting MNIST-data/t10k-images-idx3-ubyte.gz
# Extracting MNIST-data/t10k-labels-idx1-ubyte.gz

# %%
train_data = mnist.train.images
train_labels = np.asarray(mnist.train.labels, dtype=np.int32)

# %%
test_data = mnist.test.images
test_labels = np.asarray(mnist.test.labels, dtype=np.int32)

# %%
train_data = train_data.reshape([-1,28,28,1])
test_data = test_data.reshape([-1,28,28,1])

# %%
mnist_classifier = tf.estimator.Estimator(model_fn=model_fn, model_dir=logdir)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/content/drive/My Drive/Sem 7/DeepDOT/logs', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5360d591d0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tensors_to_log = {"accuracy": "accuracy"}
logging_hook = tf.train.LoggingTensorHook(tensors=tensors_to_log, every_n_iter=50)

# %%
train_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={"x": train_data},
  y=train_labels,
  batch_size=batch_size,
  num_epochs=None,
  shuffle=True)

# %%
mnist_classifier.train(
    input_fn=train_input_fn,
    steps=num_steps,
    hooks=[logging_hook])
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# INFO:tensorflow:accuracy = 0.115
# INFO:tensorflow:loss = 2.3011487, step = 1
# INFO:tensorflow:accuracy = 0.1 (22.699 sec)
# INFO:tensorflow:global_step/sec: 2.21581
# INFO:tensorflow:accuracy = 0.14 (22.433 sec)
# INFO:tensorflow:loss = 2.2979445, step = 101 (45.131 sec)
# INFO:tensorflow:accuracy = 0.155 (22.760 sec)
# INFO:tensorflow:global_step/sec: 2.21218
# INFO:tensorflow:accuracy = 0.14 (22.449 sec)
# INFO:tensorflow:loss = 2.2768524, step = 201 (45.209 sec)
# INFO:tensorflow:accuracy = 0.135 (22.493 sec)
# INFO:tensorflow:global_step/sec: 2.21614
# INFO:tensorflow:accuracy = 0.19 (22.628 sec)
# INFO:tensorflow:loss = 2.2767992, step = 301 (45.120 sec)
# INFO:tensorflow:accuracy = 0.19 (22.577 sec)
# INFO:tensorflow:global_step/sec: 2.22068
# INFO:tensorflow:accuracy = 0.21 (22.453 sec)
# INFO:tensorflow:loss = 2.2338474, step = 401 (45.030 sec)
# INFO:tensorflow:accuracy = 0.195 (22.502 sec)
# INFO:tensorflow:global_step/sec: 2.22169
# INFO:tensorflow:accuracy = 0.255 (22.512 sec)
# INFO:tensorflow:loss = 2.2184434, step = 501 (45.014 sec)
# INFO:tensorflow:accuracy = 0.225 (22.661 sec)
# INFO:tensorflow:global_step/sec: 2.21929
# INFO:tensorflow:accuracy = 0.295 (22.396 sec)
# INFO:tensorflow:loss = 2.1947005, step = 601 (45.058 sec)
# INFO:tensorflow:accuracy = 0.335 (22.482 sec)
# INFO:tensorflow:global_step/sec: 2.22396
# INFO:tensorflow:accuracy = 0.355 (22.482 sec)
# INFO:tensorflow:loss = 2.1672146, step = 701 (44.963 sec)
# INFO:tensorflow:accuracy = 0.305 (22.554 sec)
# INFO:tensorflow:global_step/sec: 2.21654
# INFO:tensorflow:accuracy = 0.375 (22.561 sec)
# INFO:tensorflow:loss = 2.1331213, step = 801 (45.116 sec)
# INFO:tensorflow:accuracy = 0.385 (22.560 sec)
# INFO:tensorflow:global_step/sec: 2.21733
# INFO:tensorflow:accuracy = 0.45 (22.540 sec)
# INFO:tensorflow:loss = 2.0761704, step = 901 (45.103 sec)
# INFO:tensorflow:accuracy = 0.48 (22.409 sec)
# INFO:tensorflow:global_step/sec: 2.22053
# INFO:tensorflow:accuracy = 0.44 (22.627 sec)
# INFO:tensorflow:loss = 2.025865, step = 1001 (45.033 sec)
# INFO:tensorflow:accuracy = 0.49 (22.673 sec)
# INFO:tensorflow:global_step/sec: 2.2179
# INFO:tensorflow:accuracy = 0.5 (22.413 sec)
# INFO:tensorflow:loss = 1.9326168, step = 1101 (45.085 sec)
# INFO:tensorflow:accuracy = 0.53 (22.459 sec)
# INFO:tensorflow:global_step/sec: 2.21897
# INFO:tensorflow:accuracy = 0.535 (22.608 sec)
# INFO:tensorflow:loss = 1.7586663, step = 1201 (45.066 sec)
# INFO:tensorflow:accuracy = 0.565 (22.730 sec)
# INFO:tensorflow:global_step/sec: 2.21219
# INFO:tensorflow:accuracy = 0.55 (22.472 sec)
# INFO:tensorflow:loss = 1.6543837, step = 1301 (45.203 sec)
# INFO:tensorflow:Saving checkpoints for 1331 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# INFO:tensorflow:accuracy = 0.525 (22.650 sec)
# INFO:tensorflow:global_step/sec: 2.21627
# INFO:tensorflow:accuracy = 0.67 (22.475 sec)
# INFO:tensorflow:loss = 1.443898, step = 1401 (45.124 sec)
# INFO:tensorflow:accuracy = 0.545 (22.569 sec)
# INFO:tensorflow:global_step/sec: 2.21513
# INFO:tensorflow:accuracy = 0.585 (22.576 sec)
# INFO:tensorflow:loss = 1.4196723, step = 1501 (45.145 sec)
# INFO:tensorflow:accuracy = 0.66 (22.464 sec)
# INFO:tensorflow:global_step/sec: 2.2281
# INFO:tensorflow:accuracy = 0.68 (22.413 sec)
# INFO:tensorflow:loss = 1.1968526, step = 1601 (44.877 sec)
# INFO:tensorflow:accuracy = 0.68 (22.509 sec)
# INFO:tensorflow:global_step/sec: 2.21892
# INFO:tensorflow:accuracy = 0.685 (22.562 sec)
# INFO:tensorflow:loss = 1.0987709, step = 1701 (45.073 sec)
# INFO:tensorflow:accuracy = 0.685 (22.527 sec)
# INFO:tensorflow:global_step/sec: 2.21698
# INFO:tensorflow:accuracy = 0.695 (22.576 sec)
# INFO:tensorflow:loss = 1.0270194, step = 1801 (45.105 sec)
# INFO:tensorflow:accuracy = 0.72 (22.503 sec)
# INFO:tensorflow:global_step/sec: 2.22158
# INFO:tensorflow:accuracy = 0.685 (22.509 sec)
# INFO:tensorflow:loss = 1.0481105, step = 1901 (45.009 sec)
# INFO:tensorflow:accuracy = 0.69 (22.708 sec)
# INFO:tensorflow:global_step/sec: 2.21069
# INFO:tensorflow:accuracy = 0.685 (22.526 sec)
# INFO:tensorflow:loss = 0.97803056, step = 2001 (45.234 sec)
# INFO:tensorflow:accuracy = 0.75 (22.507 sec)
# INFO:tensorflow:global_step/sec: 2.21965
# INFO:tensorflow:accuracy = 0.745 (22.546 sec)
# INFO:tensorflow:loss = 0.7820719, step = 2101 (45.054 sec)
# INFO:tensorflow:accuracy = 0.78 (22.576 sec)
# INFO:tensorflow:global_step/sec: 2.21436
# INFO:tensorflow:accuracy = 0.83 (22.586 sec)
# INFO:tensorflow:loss = 0.7002991, step = 2201 (45.162 sec)
# INFO:tensorflow:accuracy = 0.8 (22.467 sec)
# INFO:tensorflow:global_step/sec: 2.22247
# INFO:tensorflow:accuracy = 0.775 (22.526 sec)
# INFO:tensorflow:loss = 0.7373993, step = 2301 (44.993 sec)
# INFO:tensorflow:accuracy = 0.8 (22.484 sec)
# INFO:tensorflow:global_step/sec: 2.2236
# INFO:tensorflow:accuracy = 0.81 (22.488 sec)
# INFO:tensorflow:loss = 0.58231443, step = 2401 (44.975 sec)
# INFO:tensorflow:accuracy = 0.765 (22.450 sec)
# INFO:tensorflow:global_step/sec: 2.22329
# INFO:tensorflow:accuracy = 0.8 (22.527 sec)
# INFO:tensorflow:loss = 0.58864343, step = 2501 (44.974 sec)
# INFO:tensorflow:accuracy = 0.82 (22.425 sec)
# INFO:tensorflow:global_step/sec: 2.22587
# INFO:tensorflow:accuracy = 0.785 (22.505 sec)
# INFO:tensorflow:loss = 0.68359286, step = 2601 (44.931 sec)
# INFO:tensorflow:accuracy = 0.785 (22.700 sec)
# INFO:tensorflow:Saving checkpoints for 2663 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.19874
# INFO:tensorflow:accuracy = 0.8 (22.782 sec)
# INFO:tensorflow:loss = 0.62316465, step = 2701 (45.481 sec)
# INFO:tensorflow:accuracy = 0.825 (22.501 sec)
# INFO:tensorflow:global_step/sec: 2.21516
# INFO:tensorflow:accuracy = 0.84 (22.640 sec)
# INFO:tensorflow:loss = 0.5707304, step = 2801 (45.140 sec)
# INFO:tensorflow:accuracy = 0.8 (22.670 sec)
# INFO:tensorflow:global_step/sec: 2.2047
# INFO:tensorflow:accuracy = 0.835 (22.685 sec)
# INFO:tensorflow:loss = 0.4723226, step = 2901 (45.356 sec)
# INFO:tensorflow:accuracy = 0.865 (22.622 sec)
# INFO:tensorflow:global_step/sec: 2.20312
# INFO:tensorflow:accuracy = 0.85 (22.771 sec)
# INFO:tensorflow:loss = 0.5272012, step = 3001 (45.394 sec)
# INFO:tensorflow:accuracy = 0.855 (22.622 sec)
# INFO:tensorflow:global_step/sec: 2.21733
# INFO:tensorflow:accuracy = 0.855 (22.477 sec)
# INFO:tensorflow:loss = 0.5382036, step = 3101 (45.099 sec)
# INFO:tensorflow:accuracy = 0.8 (22.655 sec)
# INFO:tensorflow:global_step/sec: 2.21732
# INFO:tensorflow:accuracy = 0.81 (22.445 sec)
# INFO:tensorflow:loss = 0.6291019, step = 3201 (45.100 sec)
# INFO:tensorflow:accuracy = 0.805 (22.607 sec)
# INFO:tensorflow:global_step/sec: 2.20673
# INFO:tensorflow:accuracy = 0.85 (22.710 sec)
# INFO:tensorflow:loss = 0.46642587, step = 3301 (45.317 sec)
# INFO:tensorflow:accuracy = 0.875 (22.529 sec)
# INFO:tensorflow:global_step/sec: 2.22295
# INFO:tensorflow:accuracy = 0.855 (22.455 sec)
# INFO:tensorflow:loss = 0.4706179, step = 3401 (44.984 sec)
# INFO:tensorflow:accuracy = 0.835 (22.587 sec)
# INFO:tensorflow:global_step/sec: 2.22191
# INFO:tensorflow:accuracy = 0.835 (22.419 sec)
# INFO:tensorflow:loss = 0.5020763, step = 3501 (45.006 sec)
# INFO:tensorflow:accuracy = 0.855 (22.532 sec)
# INFO:tensorflow:global_step/sec: 2.22077
# INFO:tensorflow:accuracy = 0.87 (22.495 sec)
# INFO:tensorflow:loss = 0.46876892, step = 3601 (45.029 sec)
# INFO:tensorflow:accuracy = 0.84 (22.511 sec)
# INFO:tensorflow:global_step/sec: 2.22422
# INFO:tensorflow:accuracy = 0.89 (22.450 sec)
# INFO:tensorflow:loss = 0.4223059, step = 3701 (44.960 sec)
# INFO:tensorflow:accuracy = 0.845 (22.418 sec)
# INFO:tensorflow:global_step/sec: 2.22885
# INFO:tensorflow:accuracy = 0.86 (22.447 sec)
# INFO:tensorflow:loss = 0.49698845, step = 3801 (44.864 sec)
# INFO:tensorflow:accuracy = 0.89 (22.537 sec)
# INFO:tensorflow:global_step/sec: 2.18888
# INFO:tensorflow:accuracy = 0.855 (23.148 sec)
# INFO:tensorflow:loss = 0.45900285, step = 3901 (45.685 sec)
# INFO:tensorflow:accuracy = 0.87 (23.830 sec)
# INFO:tensorflow:Saving checkpoints for 3988 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.10533
# INFO:tensorflow:accuracy = 0.89 (23.669 sec)
# INFO:tensorflow:loss = 0.43041244, step = 4001 (47.499 sec)
# INFO:tensorflow:accuracy = 0.88 (23.853 sec)
# INFO:tensorflow:global_step/sec: 2.06891
# INFO:tensorflow:accuracy = 0.855 (24.484 sec)
# INFO:tensorflow:loss = 0.493785, step = 4101 (48.338 sec)
# INFO:tensorflow:accuracy = 0.875 (23.348 sec)
# INFO:tensorflow:global_step/sec: 2.16525
# INFO:tensorflow:accuracy = 0.89 (22.836 sec)
# INFO:tensorflow:loss = 0.42288712, step = 4201 (46.182 sec)
# INFO:tensorflow:accuracy = 0.875 (22.694 sec)
# INFO:tensorflow:global_step/sec: 2.1863
# INFO:tensorflow:accuracy = 0.855 (23.045 sec)
# INFO:tensorflow:loss = 0.4706714, step = 4301 (45.740 sec)
# INFO:tensorflow:accuracy = 0.855 (23.012 sec)
# INFO:tensorflow:global_step/sec: 2.18227
# INFO:tensorflow:accuracy = 0.885 (22.809 sec)
# INFO:tensorflow:loss = 0.4170186, step = 4401 (45.821 sec)
# INFO:tensorflow:accuracy = 0.905 (22.991 sec)
# INFO:tensorflow:global_step/sec: 2.19164
# INFO:tensorflow:accuracy = 0.865 (22.638 sec)
# INFO:tensorflow:loss = 0.44058052, step = 4501 (45.629 sec)
# INFO:tensorflow:accuracy = 0.865 (22.906 sec)
# INFO:tensorflow:global_step/sec: 2.19014
# INFO:tensorflow:accuracy = 0.935 (22.752 sec)
# INFO:tensorflow:loss = 0.25056747, step = 4601 (45.658 sec)
# INFO:tensorflow:accuracy = 0.855 (22.673 sec)
# INFO:tensorflow:global_step/sec: 2.20429
# INFO:tensorflow:accuracy = 0.895 (22.696 sec)
# INFO:tensorflow:loss = 0.32243022, step = 4701 (45.370 sec)
# INFO:tensorflow:accuracy = 0.885 (22.723 sec)
# INFO:tensorflow:global_step/sec: 2.20838
# INFO:tensorflow:accuracy = 0.89 (22.561 sec)
# INFO:tensorflow:loss = 0.3843412, step = 4801 (45.284 sec)
# INFO:tensorflow:accuracy = 0.895 (22.511 sec)
# INFO:tensorflow:global_step/sec: 2.21895
# INFO:tensorflow:accuracy = 0.89 (22.551 sec)
# INFO:tensorflow:loss = 0.39297858, step = 4901 (45.062 sec)
# INFO:tensorflow:accuracy = 0.875 (22.756 sec)
# INFO:tensorflow:global_step/sec: 2.20662
# INFO:tensorflow:accuracy = 0.895 (22.564 sec)
# INFO:tensorflow:loss = 0.32143718, step = 5001 (45.319 sec)
# INFO:tensorflow:accuracy = 0.895 (22.613 sec)
# INFO:tensorflow:global_step/sec: 2.2143
# INFO:tensorflow:accuracy = 0.88 (22.549 sec)
# INFO:tensorflow:loss = 0.37322468, step = 5101 (45.163 sec)
# INFO:tensorflow:accuracy = 0.905 (22.821 sec)
# INFO:tensorflow:global_step/sec: 2.20115
# INFO:tensorflow:accuracy = 0.895 (22.608 sec)
# INFO:tensorflow:loss = 0.41556865, step = 5201 (45.427 sec)
# INFO:tensorflow:accuracy = 0.89 (22.688 sec)
# INFO:tensorflow:Saving checkpoints for 5300 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.20377
# INFO:tensorflow:accuracy = 0.915 (22.688 sec)
# INFO:tensorflow:loss = 0.31537974, step = 5301 (45.376 sec)
# INFO:tensorflow:accuracy = 0.92 (22.818 sec)
# INFO:tensorflow:global_step/sec: 2.20314
# INFO:tensorflow:accuracy = 0.895 (22.575 sec)
# INFO:tensorflow:loss = 0.40271938, step = 5401 (45.396 sec)
# INFO:tensorflow:accuracy = 0.885 (22.572 sec)
# INFO:tensorflow:global_step/sec: 2.20474
# INFO:tensorflow:accuracy = 0.925 (22.784 sec)
# INFO:tensorflow:loss = 0.2983959, step = 5501 (45.354 sec)
# INFO:tensorflow:accuracy = 0.94 (23.854 sec)
# INFO:tensorflow:global_step/sec: 2.12287
# INFO:tensorflow:accuracy = 0.905 (23.250 sec)
# INFO:tensorflow:loss = 0.30617255, step = 5601 (47.103 sec)
# INFO:tensorflow:accuracy = 0.93 (23.103 sec)
# INFO:tensorflow:global_step/sec: 2.18772
# INFO:tensorflow:accuracy = 0.89 (22.608 sec)
# INFO:tensorflow:loss = 0.2945997, step = 5701 (45.711 sec)
# INFO:tensorflow:accuracy = 0.885 (23.002 sec)
# INFO:tensorflow:global_step/sec: 2.17915
# INFO:tensorflow:accuracy = 0.915 (22.887 sec)
# INFO:tensorflow:loss = 0.28821415, step = 5801 (45.889 sec)
# INFO:tensorflow:accuracy = 0.9 (22.572 sec)
# INFO:tensorflow:global_step/sec: 2.2107
# INFO:tensorflow:accuracy = 0.92 (22.662 sec)
# INFO:tensorflow:loss = 0.25880215, step = 5901 (45.234 sec)
# INFO:tensorflow:accuracy = 0.92 (22.680 sec)
# INFO:tensorflow:global_step/sec: 2.20548
# INFO:tensorflow:accuracy = 0.905 (22.663 sec)
# INFO:tensorflow:loss = 0.3412687, step = 6001 (45.343 sec)
# INFO:tensorflow:accuracy = 0.92 (22.622 sec)
# INFO:tensorflow:global_step/sec: 2.22127
# INFO:tensorflow:accuracy = 0.92 (22.395 sec)
# INFO:tensorflow:loss = 0.24200809, step = 6101 (45.017 sec)
# INFO:tensorflow:accuracy = 0.93 (22.538 sec)
# INFO:tensorflow:global_step/sec: 2.21998
# INFO:tensorflow:accuracy = 0.94 (22.511 sec)
# INFO:tensorflow:loss = 0.2299531, step = 6201 (45.049 sec)
# INFO:tensorflow:accuracy = 0.915 (22.711 sec)
# INFO:tensorflow:global_step/sec: 2.20498
# INFO:tensorflow:accuracy = 0.91 (22.639 sec)
# INFO:tensorflow:loss = 0.35982215, step = 6301 (45.350 sec)
# INFO:tensorflow:accuracy = 0.91 (22.598 sec)
# INFO:tensorflow:global_step/sec: 2.21646
# INFO:tensorflow:accuracy = 0.93 (22.517 sec)
# INFO:tensorflow:loss = 0.25663406, step = 6401 (45.116 sec)
# INFO:tensorflow:accuracy = 0.915 (22.538 sec)
# INFO:tensorflow:global_step/sec: 2.21261
# INFO:tensorflow:accuracy = 0.93 (22.661 sec)
# INFO:tensorflow:loss = 0.2734707, step = 6501 (45.198 sec)
# INFO:tensorflow:accuracy = 0.915 (22.465 sec)
# INFO:tensorflow:global_step/sec: 2.22014
# INFO:tensorflow:accuracy = 0.94 (22.577 sec)
# INFO:tensorflow:loss = 0.24531169, step = 6601 (45.043 sec)
# INFO:tensorflow:Saving checkpoints for 6621 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:accuracy = 0.93 (22.531 sec)
# INFO:tensorflow:global_step/sec: 2.22064
# INFO:tensorflow:accuracy = 0.92 (22.500 sec)
# INFO:tensorflow:loss = 0.27135, step = 6701 (45.030 sec)
# INFO:tensorflow:accuracy = 0.93 (22.652 sec)
# INFO:tensorflow:global_step/sec: 2.21774
# INFO:tensorflow:accuracy = 0.94 (22.437 sec)
# INFO:tensorflow:loss = 0.2211483, step = 6801 (45.090 sec)
# INFO:tensorflow:accuracy = 0.915 (22.434 sec)
# INFO:tensorflow:global_step/sec: 2.22206
# INFO:tensorflow:accuracy = 0.925 (22.573 sec)
# INFO:tensorflow:loss = 0.24649152, step = 6901 (45.006 sec)
# INFO:tensorflow:accuracy = 0.94 (22.382 sec)
# INFO:tensorflow:global_step/sec: 2.2282
# INFO:tensorflow:accuracy = 0.945 (22.497 sec)
# INFO:tensorflow:loss = 0.23224665, step = 7001 (44.880 sec)
# INFO:tensorflow:accuracy = 0.9 (22.372 sec)
# INFO:tensorflow:global_step/sec: 2.21712
# INFO:tensorflow:accuracy = 0.915 (22.727 sec)
# INFO:tensorflow:loss = 0.27352276, step = 7101 (45.099 sec)
# INFO:tensorflow:accuracy = 0.94 (22.490 sec)
# INFO:tensorflow:global_step/sec: 2.22609
# INFO:tensorflow:accuracy = 0.905 (22.436 sec)
# INFO:tensorflow:loss = 0.3716917, step = 7201 (44.926 sec)
# INFO:tensorflow:accuracy = 0.915 (22.407 sec)
# INFO:tensorflow:global_step/sec: 2.23023
# INFO:tensorflow:accuracy = 0.92 (22.428 sec)
# INFO:tensorflow:loss = 0.28024042, step = 7301 (44.835 sec)
# INFO:tensorflow:accuracy = 0.965 (22.377 sec)
# INFO:tensorflow:global_step/sec: 2.2347
# INFO:tensorflow:accuracy = 0.925 (22.373 sec)
# INFO:tensorflow:loss = 0.29815698, step = 7401 (44.751 sec)
# INFO:tensorflow:accuracy = 0.905 (22.556 sec)
# INFO:tensorflow:global_step/sec: 2.22622
# INFO:tensorflow:accuracy = 0.92 (22.363 sec)
# INFO:tensorflow:loss = 0.30388072, step = 7501 (44.919 sec)
# INFO:tensorflow:accuracy = 0.905 (22.358 sec)
# INFO:tensorflow:global_step/sec: 2.22331
# INFO:tensorflow:accuracy = 0.915 (22.620 sec)
# INFO:tensorflow:loss = 0.2829456, step = 7601 (44.979 sec)
# INFO:tensorflow:accuracy = 0.92 (22.307 sec)
# INFO:tensorflow:global_step/sec: 2.23299
# INFO:tensorflow:accuracy = 0.91 (22.477 sec)
# INFO:tensorflow:loss = 0.26508918, step = 7701 (44.784 sec)
# INFO:tensorflow:accuracy = 0.93 (22.360 sec)
# INFO:tensorflow:global_step/sec: 2.23414
# INFO:tensorflow:accuracy = 0.9 (22.397 sec)
# INFO:tensorflow:loss = 0.34938255, step = 7801 (44.760 sec)
# INFO:tensorflow:accuracy = 0.93 (22.570 sec)
# INFO:tensorflow:global_step/sec: 2.22571
# INFO:tensorflow:accuracy = 0.93 (22.361 sec)
# INFO:tensorflow:loss = 0.24428216, step = 7901 (44.930 sec)
# INFO:tensorflow:accuracy = 0.905 (22.504 sec)
# INFO:tensorflow:Saving checkpoints for 7957 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.22015
# INFO:tensorflow:accuracy = 0.94 (22.536 sec)
# INFO:tensorflow:loss = 0.22741285, step = 8001 (45.038 sec)
# INFO:tensorflow:accuracy = 0.91 (22.587 sec)
# INFO:tensorflow:global_step/sec: 2.22107
# INFO:tensorflow:accuracy = 0.925 (22.437 sec)
# INFO:tensorflow:loss = 0.24412541, step = 8101 (45.024 sec)
# INFO:tensorflow:accuracy = 0.91 (22.659 sec)
# INFO:tensorflow:global_step/sec: 2.21749
# INFO:tensorflow:accuracy = 0.91 (22.438 sec)
# INFO:tensorflow:loss = 0.25224507, step = 8201 (45.098 sec)
# INFO:tensorflow:accuracy = 0.925 (22.462 sec)
# INFO:tensorflow:global_step/sec: 2.21455
# INFO:tensorflow:accuracy = 0.905 (22.695 sec)
# INFO:tensorflow:loss = 0.27926502, step = 8301 (45.156 sec)
# INFO:tensorflow:accuracy = 0.925 (22.508 sec)
# INFO:tensorflow:global_step/sec: 2.22226
# INFO:tensorflow:accuracy = 0.925 (22.488 sec)
# INFO:tensorflow:loss = 0.19311623, step = 8401 (44.996 sec)
# INFO:tensorflow:accuracy = 0.92 (22.548 sec)
# INFO:tensorflow:global_step/sec: 2.22429
# INFO:tensorflow:accuracy = 0.965 (22.413 sec)
# INFO:tensorflow:loss = 0.14628159, step = 8501 (44.961 sec)
# INFO:tensorflow:accuracy = 0.93 (22.441 sec)
# INFO:tensorflow:global_step/sec: 2.22083
# INFO:tensorflow:accuracy = 0.935 (22.587 sec)
# INFO:tensorflow:loss = 0.2549464, step = 8601 (45.028 sec)
# INFO:tensorflow:accuracy = 0.915 (22.403 sec)
# INFO:tensorflow:global_step/sec: 2.2317
# INFO:tensorflow:accuracy = 0.92 (22.408 sec)
# INFO:tensorflow:loss = 0.2584997, step = 8701 (44.811 sec)
# INFO:tensorflow:accuracy = 0.92 (22.459 sec)
# INFO:tensorflow:global_step/sec: 2.22438
# INFO:tensorflow:accuracy = 0.93 (22.495 sec)
# INFO:tensorflow:loss = 0.23763847, step = 8801 (44.955 sec)
# INFO:tensorflow:accuracy = 0.905 (22.655 sec)
# INFO:tensorflow:global_step/sec: 2.21245
# INFO:tensorflow:accuracy = 0.91 (22.544 sec)
# INFO:tensorflow:loss = 0.2662375, step = 8901 (45.199 sec)
# INFO:tensorflow:accuracy = 0.96 (22.643 sec)
# INFO:tensorflow:global_step/sec: 2.21728
# INFO:tensorflow:accuracy = 0.975 (22.455 sec)
# INFO:tensorflow:loss = 0.1476382, step = 9001 (45.101 sec)
# INFO:tensorflow:accuracy = 0.945 (22.617 sec)
# INFO:tensorflow:global_step/sec: 2.21367
# INFO:tensorflow:accuracy = 0.955 (22.556 sec)
# INFO:tensorflow:loss = 0.17554228, step = 9101 (45.170 sec)
# INFO:tensorflow:accuracy = 0.915 (22.453 sec)
# INFO:tensorflow:global_step/sec: 2.22691
# INFO:tensorflow:accuracy = 0.93 (22.451 sec)
# INFO:tensorflow:loss = 0.22779106, step = 9201 (44.904 sec)
# INFO:tensorflow:accuracy = 0.895 (22.597 sec)
# INFO:tensorflow:Saving checkpoints for 9290 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.20915
# INFO:tensorflow:accuracy = 0.915 (22.674 sec)
# INFO:tensorflow:loss = 0.2788495, step = 9301 (45.271 sec)
# INFO:tensorflow:accuracy = 0.915 (22.513 sec)
# INFO:tensorflow:global_step/sec: 2.22211
# INFO:tensorflow:accuracy = 0.93 (22.485 sec)
# INFO:tensorflow:loss = 0.2500167, step = 9401 (44.998 sec)
# INFO:tensorflow:accuracy = 0.915 (22.435 sec)
# INFO:tensorflow:global_step/sec: 2.21727
# INFO:tensorflow:accuracy = 0.935 (22.665 sec)
# INFO:tensorflow:loss = 0.23177591, step = 9501 (45.104 sec)
# INFO:tensorflow:accuracy = 0.955 (22.523 sec)
# INFO:tensorflow:global_step/sec: 2.22183
# INFO:tensorflow:accuracy = 0.925 (22.490 sec)
# INFO:tensorflow:loss = 0.22356062, step = 9601 (45.010 sec)
# INFO:tensorflow:accuracy = 0.93 (22.563 sec)
# INFO:tensorflow:global_step/sec: 2.22169
# INFO:tensorflow:accuracy = 0.935 (22.447 sec)
# INFO:tensorflow:loss = 0.20645133, step = 9701 (45.010 sec)
# INFO:tensorflow:accuracy = 0.92 (22.452 sec)
# INFO:tensorflow:global_step/sec: 2.22261
# INFO:tensorflow:accuracy = 0.925 (22.540 sec)
# INFO:tensorflow:loss = 0.2647801, step = 9801 (44.991 sec)
# INFO:tensorflow:accuracy = 0.955 (22.431 sec)
# INFO:tensorflow:global_step/sec: 2.22504
# INFO:tensorflow:accuracy = 0.87 (22.511 sec)
# INFO:tensorflow:loss = 0.3900126, step = 9901 (44.942 sec)
# INFO:tensorflow:accuracy = 0.935 (22.476 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /content/drive/My Drive/Sem 7/DeepDOT/logs/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3024564.
